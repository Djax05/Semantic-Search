# %%
import pandas as pd
import json
from pydantic import BaseModel, Field
from openai import OpenAI
from google.colab import userdata
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# %%
from datasets import load_dataset
from sentence_transformers import SentenceTransformer
from sklearn.neighbors import NearestNeighbors

# %%
print("load dataset...")
dataset = load_dataset("ag_news", split="train[:1000]")

documents = dataset["text"]

print(f"loaded {len(documents)} documents.")
print(f"Sample: {documents[0][:100]}...")

# %%
print("Loading embedding model...")
model = SentenceTransformer("all-MiniLM-L6-v2")

print("Encoding documents (This may take a few seconds) ...")
document_embeddings = model.encode(documents, show_progress_bar=True)
print(f"created {document_embeddings.shape[0]} embeddings.")

# %%
search_engine = NearestNeighbors(n_neighbors=5, metric="cosine")

search_engine.fit(document_embeddings)

print("Search engine is ready")
# Out:
# Search engine is ready

# %%
def semantic_search(query, top_k=10):
    query_embeddings = model.encode([query])

    distances, indices = search_engine.kneighbors(query_embeddings, n_neighbors=top_k)

    for i in range(top_k):
        doc_idx = indices[0][i]

        similarity = 1 - distances[0][i]

        print(f"Result no. {i + 1} (Similarity: {similarity:.4f})")
        print(f"Text: {documents[int(doc_idx)][:150]}...\n")

# %%
semantic_search("The animals around the world")
# Out:
# Result no. 1 (Similarity: 0.3793)
# Text: 266 Chimps From Lab Adopted by Florida Refuge With an influx of chimps previously used as laboratory animals, Florida's Center for Captive Chimpanzee ...
#
# Result no. 2 (Similarity: 0.3668)
# Text: India makes elephants appeal Indian asks Bangladesh to spare the lives of around 100 elephants which have strayed across the border....
#
# Result no. 3 (Similarity: 0.3656)
# Text: Dolphins Too Have Born Socialites (Reuters) Reuters - Some people are born to be the life and\soul of the party -- and so it seems are some dolphins....
#
# Result no. 4 (Similarity: 0.3160)
# Text: Ancient Olympics Mixed Naked Sports, Pagan Partying Nude athletes, performance-enhancing lizard meat, and animal sacrifices are just a few of the thin...
#
# Result no. 5 (Similarity: 0.3115)
# Text: Poachers Putting Endangered Rhinos at Risk (AP) AP - Gangs of poachers in Congo have been slaughtering the world's minuscule population of northern wh...
#
# ...

# %%
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
username = "Djax05"
repo = "Semantic-Search"

import subprocess
subprocess.run(
    ['git', 'remote', 'set-url', 'origin',
     f'https://{username}:{token}@github.com/{username}/{repo}.git'],
    capture_output=True
)

# !git add "Semantic Search.ipynb"
# !git commit -m "Clean up notebook"
result = subprocess.run(['git', 'push'], capture_output=True)
print("Done!" if result.returncode == 0 else result.stderr.decode())
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Done!

# %%
# !git push
# Out:
# Everything up-to-date

# %%
# !git log
# Out:
# commit 489f4179fc0b13e3cd62ca03a485260860bee887 (HEAD -> main, origin/main, origin/HEAD)
# Author: Makinde John <mackjohn341@gmail.com>
# Date:   Sun Apr 5 12:52:29 2026 +0000
#
#     Fix widget metadata error
#
# commit 297aeeecbbbaf2c10bbc3f2f8663c7fd25d7347a
# Author: Makinde John <mackjohn341@gmail.com>
# Date:   Wed Mar 18 11:55:01 2026 +0000
#
#     Add Semantic Search notebook
#
# commit 990a2838bd0492556ecb1a876b0cb8fe3eb7f20d
# Author: Makinde John <159927546+Djax05@users.noreply.github.com>
# Date:   Wed Mar 18 01:04:37 2026 +0100
#
#     Implement a semantic search engine

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Semantic Search.ipynb" "/content/drive/MyDrive/Semantic-Search/Semantic-Search.ipynb"
# Out:
# cp: cannot create regular file '/content/Semantic-Search/Semantic-Search.ipynb': No such file or directory

# %%
# %ls
# Out:
# '230805535 MAKINDE JOhn OLadimeji.pkt'
# 'Colab Notebooks'/
# 'Copy of 18.pdf'
# 'Copy of Commercialization By Ayobade.pdf'
# 'Copy of CSC 316 Group 1 META Gantt chart.gsheet'
# 'Copy of Industrial Social Work sow 246.pdf'
# 'Copy of SOW226 246 NOTE 2.pptx'
# 'CSC 316.gdoc'
# 'Diabetes Hackathon'/
#  Doyin/
# 'GROUP 10 CSC 410'/
# 'GROUP 28 CSC 436'/
# 'Group 28 Edulearn LMS project CSC 436.pdf'
#  IMG-20240124-WA0036.jpg
# 'Important school documents'/
#  Lucidchart/
# 'Makinde John Oladimeji 2nd Java concurrency Exercise.odt'
#  Makinde_John_Oladimeji_Admission_Letter.PDF
# 'Pneumonia Hackathon'/
#  Receipt_032g0fg04bc03.jpg
# 'Receipt_032losizb4802 (1).jpg'
#  Receipt_1772530054457.pdf
# 'Resources for our System Analysis Project'/
# 'security system model.drawio'
# 'security system model.drawio.png'
#  Semantic-Search/
# 'StudentResult Makinde Doyinsolami.pdf'
# 'StudentResult Makinde John.pdf'
# 'To-do list (1).gsheet'
# 'To-do list (2).gsheet'
# 'To-do list (3).gsheet'
# ...
